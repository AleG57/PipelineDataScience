# %% [markdown]
# # Neural Networks
#
# Les réseaux de neuronnes sont des graphes orientés (acycliques pour les réseaux Feedforwad et au moins un cycle pour les réseaux récurrents).
#
# <div align="center">
#   <img src="src/pics/FFNN/FNN-vs-RNN.webp" alt="a" width="750" height="500">
# </div>

# %% [markdown]
# * La couche de max pooling permet de créer de l'invariance dans le modèle (par exmeple, pour MNIST,  quand on a plusieurs images de "2", on veut toujours que le modèle prédise la classe "2" peut importe la forme du 2.
#
# * On génère des superdatasets (i.e. datasets constitués de plusieurs versions bruitées d'instances du dataset original) puis on entraîne un modèle sur une version du dataset chacun. On en extrait la moyenne des résultats.
