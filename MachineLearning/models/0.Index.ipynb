# %% [markdown]
# # Liste des modèles
# ---
#
# * [Naive Bayes](1.NaiveBayes.ipynb)
#     * Naive Bayes <span style="color: red;">non fait -> code sur plusieurs exemples</span>
# * [Analyse discriminante](2.DiscriminantAnalysis.ipynb)
#     * QDA <span style="color: red;">non fait -> code</span>
#     * LDA <span style="color: red;">non fait -> code</span>
# * [Modèles de mixture et algorithme EM](3.MixtureModels.ipynb)
#     * Algorithme EM <span style="color: red;">non fait</span>
# * [Régression linéaire](4.LinearRegression.ipynb)
#     * Régression linéaire simple <span style="color: green;">fait</span>
#     * Régression linéaire multiple <span style="color: green;">fait</span>
#     * Régressions régularisées
#         * Ridge <span style="color: green;">fait</span>
#         * Lasso <span style="color: green;">fait</span>
#         * ElasticNet <span style="color: green;">fait</span>
#     * PLS <span style="color: green;">fait</span>
#     * GLM <span style="color: green;">fait</span>
# * [Régression logistique](5.LogisticRegression.ipynb)
#     * Régression logistique <span style="color: green;">fait</span>
# * [Random forest](6.RandomForest.ipynb)
#     * Random forest
#         * Random forest classifier <span style="color: green;">fait</span>
#         * Random forest regressor <span style="color: green;">fait</span>
#     * Isolation forest <span style="color: red;">non fait</span>
# * [Support Vector Machines](7.SVM.ipynb)
#     * SVM à marge dure <span style="color: green;">fait</span>
#     * C-SVC <span style="color: green;">fait</span>
#     * $\nu$-SVM <span style="color: green;">fait</span>
#     * SVR / $\epsilon$-SVR <span style="color: green;">fait</span>
#     * One class SVM <span style="color: red;">non fait</span>
# * [Boosting](8.Boosting.ipynb)
#     * Gradient Boosting (GB) <span style="color: red;">non fait</span>
#     * Extreme Gradient Boosting (XGBoost) <span style="color: green;">fait</span>
#     * AdaBoost <span style="color: red;">non fait</span>
#     * LightGBM <span style="color: red;">non fait</span>
# * [Processus autorégressifs](9.SARIMA.ipynb)
#     * AR <span style="color: green;">fait</span>
#     * MA <span style="color: green;">fait</span>
#     * ARMA <span style="color: green;">fait</span>
#     * SARIMA <span style="color: green;">fait</span>
#     * SARIMAX <span style="color: green;">fait</span>
#     * VARIMA <span style="color: red;">non fait</span>
#     * VARIMAX <span style="color: red;">non fait</span>
# * [Réduction de dimension](10.PCA.ipynb)
#     * PCA <span style="color: green;">fait</span>
# * [Clustering](11.Clustering.ipynb)
#     * K-means <span style="color: green;">fait</span>
#     * CAH <span style="color: green;">fait</span>
#
# # Références
# ---
# [Random forest : Leo Breiman, 2001](src/paper/RandomForest/Random_Forest.pdf)
#
# [Isolation forest : Fei Tony Liu, 2008](src/paper/IsolationForest/Isolation_Forest.pdf)
